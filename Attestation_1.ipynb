# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
url = 'https://raw.githubusercontent.com/ivankondratyev/AI_Arch_IU/main/dataset_tk.csv'
df = pd.read_csv(url)

# %%
df.rename(columns = {'Unnamed: 0':'DateTime'}, inplace = True )

# %%
df
# Out:
#                 DateTime  Punjab  Haryana  Rajasthan  Delhi     UP  \
# 0    02/01/2019 00:00:00   119.9    130.3      234.1   85.8  313.9
# 1    03/01/2019 00:00:00   121.9    133.5      240.2   85.5  311.8
# 2    04/01/2019 00:00:00   118.8    128.2      239.8   83.5  320.7
# 3    05/01/2019 00:00:00   121.0    127.5      239.1   79.2  299.0
# 4    06/01/2019 00:00:00   121.4    132.6      240.4   76.6  286.8
# ..                   ...     ...      ...        ...    ...    ...
# 498  01/12/2020 00:00:00   130.8    126.0      220.4   77.3  322.8
# 499  02/12/2020 00:00:00   129.4    127.3      218.4   81.3  331.4
# 500  03/12/2020 00:00:00   132.1    129.7      205.6   85.6  336.7
# 501  04/12/2020 00:00:00   132.1    128.4      207.0   83.9  334.6
# 502  05/12/2020 00:00:00   120.4    111.2      201.4   83.6  287.3
#
#      Uttarakhand    HP   J&K  Chandigarh  ...  Odisha  West Bengal  Sikkim  \
# 0           40.7  30.0  52.5         5.0  ...    70.2        108.2     2.0
# ...

# %%
df.shape
# Out:
# (503, 34)

# %%
df.describe(include = "all")
# Out:
#                    DateTime      Punjab     Haryana   Rajasthan       Delhi  \
# count                   503  503.000000  503.000000  503.000000  503.000000
# unique                  498         NaN         NaN         NaN         NaN
# top     12/07/2019 00:00:00         NaN         NaN         NaN         NaN
# freq                      2         NaN         NaN         NaN         NaN
# mean                    NaN  141.145527  138.333598  218.443340   83.380716
# std                     NaN   56.977361   38.106593   27.421615   25.915357
# min                     NaN   56.100000   64.800000  105.800000   41.800000
# 25%                     NaN  104.000000  114.800000  205.800000   63.500000
# 50%                     NaN  118.300000  126.800000  222.900000   72.700000
# 75%                     NaN  162.500000  158.100000  237.600000  105.800000
# max                     NaN  300.000000  237.200000  278.000000  147.100000
#
# ...

# %%
#Проверяем количество пустых ячеек
df.isnull().sum()
# Out:
# DateTime             0
# Punjab               0
# Haryana              0
# Rajasthan            0
# Delhi                0
# UP                   0
# Uttarakhand          0
# HP                   0
# J&K                  0
# Chandigarh           0
# Chhattisgarh         0
# Gujarat              0
# MP                   0
# Maharashtra          0
# Goa                  0
# DNH                  0
# Andhra Pradesh       0
# Telangana            0
# Karnataka            0
# Kerala               0
# Tamil Nadu           0
# Pondy                0
# Bihar                0
# Jharkhand            0
# Odisha               0
# West Bengal          0
# Sikkim               0
# Arunachal Pradesh    0
# Assam                0
# Manipur              0
# Meghalaya            0
# Mizoram              0
# Nagaland             0
# Tripura              0
# dtype: int64

# %%
#Построим общий график для визуальной оценки
df_plt = df.drop(['DateTime'], axis=1).plot(figsize=(15,5))

# %%
variance = df.drop(labels = ['DateTime'], axis=1).var()
print('Самое нестабильное потребление энергии в регионе', variance.idxmax(),'. Дисперсия равняется',variance.max())
print('Самое стабильное потребление энергии в регионе', variance.idxmin(),'. Дисперсия равняется',variance.min())
# Out:
# Самое нестабильное потребление энергии в регионе UP . Дисперсия равняется 4424.50594465082
# Самое стабильное потребление энергии в регионе Mizoram . Дисперсия равняется 0.020955462444456764

# %%
Total_Cons = df.drop(labels = ['DateTime'],axis=1).sum(axis=1)
Total_Cons.index = list(df['DateTime'])
print(Total_Cons)
# Out:
# 02/01/2019 00:00:00    3373.4
# 03/01/2019 00:00:00    3403.7
# 04/01/2019 00:00:00    3304.1
# 05/01/2019 00:00:00    3308.9
# 06/01/2019 00:00:00    3316.9
#                         ...
# 01/12/2020 00:00:00    3741.5
# 02/12/2020 00:00:00    3763.8
# 03/12/2020 00:00:00    3726.6
# 04/12/2020 00:00:00    3642.1
# 05/12/2020 00:00:00    3407.0
# Length: 503, dtype: float64

# %%
min_consumption = Total_Cons.min()
max_consumption = Total_Cons.max()
min_index = Total_Cons.idxmin()
max_index = Total_Cons.idxmax()

# %%
print('Минимальное общее потребление энергии было зарегистрировано',min_index,' и равнялось',min_consumption)
print('Максимальное общее потребление энергии было зарегистрировано',max_index,' и равнялось',max_consumption)
# Out:
# Минимальное общее потребление энергии было зарегистрировано 31/05/2019 00:00:00  и равнялось 2555.8
# Максимальное общее потребление энергии было зарегистрировано 24/02/2019 00:00:00  и равнялось 4059.1

# %%
total_cons_region = df.sum()
total_cons_region = total_cons_region.drop(labels = ['DateTime'])
total_cons_region = total_cons_region.sort_values(ascending=True)
print(type(total_cons_region))
total_cons_region.plot(kind='pie',autopct='%1.0f%%',figsize=(10,10))
list_total_cons_region = total_cons_region.tolist()
sum(list_total_cons_region[:15])
# Out:
# <class 'pandas.core.series.Series'>
# 85589.2

# %%
total_cons_region = pd.to_numeric(total_cons_region)

# %%
max_total_index = total_cons.idxmax()
min_total_index = total_cons.idxmin()
max_perc = round(100*total_cons[max_total_index] /total_cons.sum(),2)
min_perc = round(100*total_cons[min_total_index] /total_cons.sum(),2)

# %%
print('Максимальное потребление энергии за указанный период было в области', max_total_index,', которая потребила', max_perc,'% всей энергии')
print('Минимальное потребление энергии за указанный период было в области', min_total_index,', которая потребила', min_perc,'% всей энергии')
# Out:
# Максимальное потребление энергии за указанный период было в области Maharashtra , которая потребила 12.7 % всей энергии
# Минимальное потребление энергии за указанный период было в области Sikkim , которая потребила 0.04 % всей энергии

# %%
df_draw = df.copy()
df_draw.loc[df_draw['number'] < 20, 'aliments'] = 'vegetables'

df_draw = df_draw.groupby('aliments')['number'].sum().reset_index()

plt.pie(df_draw['number'], labels=df_draw['aliments'], autopct='%.0f%%');
